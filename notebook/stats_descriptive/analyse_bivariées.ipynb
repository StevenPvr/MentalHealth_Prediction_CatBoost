# %% [markdown]
# ## 2. analyse statistiques bivariées

# %% [markdown]
# ### a. Tableau de contingence

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency # type: ignore

# %%
file_path = "../../data/dataset.csv"
df = pd.read_csv(file_path)

# %%
def tableau_contingence(df, target='Treatment'):
    """Affiche les tableaux de contingence de toutes les variables avec la variable cible."""
    print("="*80 + f"\nTABLEAUX DE CONTINGENCE - TOUTES LES VARIABLES × {target}\n" + "="*80)
    
    resultats = {}
    for col in df.columns:
        if col == target:
            continue
        
        print(f"\n{'='*80}\nVariable : {col} × {target}\n{'='*80}")
        
        # Effectifs
        contingence = pd.crosstab(df[col], df[target], margins=True, margins_name="TOTAL")
        print("\n--- EFFECTIFS ---")
        print(contingence)
        
        # Proportions en ligne (%) - Distribution de Treatment selon la variable
        contingence_row = pd.crosstab(df[col], df[target], normalize='index') * 100
        print(f"\n--- PROPORTIONS EN LIGNE (%) - Distribution de {target} selon {col} ---")
        print(contingence_row.round(2))
        
        resultats[col] = {'effectifs': contingence, 'pct_ligne': contingence_row}
    
    print("\n" + "="*80 + "\nANALYSE TERMINÉE\n" + "="*80)
    return resultats

# Analyse de toutes les variables avec Treatment
resultats_contingence = tableau_contingence(df)
# Out:
# ================================================================================
# TABLEAUX DE CONTINGENCE - TOUTES LES VARIABLES × Treatment
# ================================================================================
#
# ================================================================================
# Variable : Gender × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment      No     Yes   TOTAL
# Gender
# Female       9406   21308   30714
# Male       123552  107062  230614
# TOTAL      132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon Gender ---
# Treatment     No    Yes
# Gender
# Female     30.62  69.38
# Male       53.58  46.42
#
# ================================================================================
# Variable : Country × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment                   No     Yes   TOTAL
# Country
# Australia                 1397    2147    3544
# Belgium                    477       0     477
# Bosnia and Herzegovina     237       0     237
# Brazil                     886     452    1338
# Canada                    6802    7375   14177
# Colombia                   384       0     384
# Costa Rica                 384       0     384
# Croatia                      0     385     385
# Czech Republic             384       0     384
# Denmark                      0     766     766
# Finland                    384       0     384
# France                    2306       0    2306
# Georgia                    384       0     384
# Germany                   2308    2307    4615
# Greece                     768       0     768
# India                     1922     643    2565
# Ireland                   2437    2691    5128
# Israel                    1537       0    1537
# Italy                     1538       0    1538
# Mexico                     384       0     384
# Moldova                      0     385     385
# Netherlands               3717    1922    5639
# New Zealand                384    1406    1790
# Nigeria                    385       0     385
# Philippines                384       0     384
# Poland                       0     637     637
# Portugal                   384       0     384
# Russia                     769       0     769
# Singapore                  770       0     770
# South Africa               769    1038    1807
# Sweden                    1785     629    2414
# Switzerland                769     769    1538
# Thailand                   385       0     385
# UK                       24580   23298   47878
# USA                      72958   81520  154478
# TOTAL                   132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon Country ---
# Treatment                   No     Yes
# Country
# Australia                39.42   60.58
# Belgium                 100.00    0.00
# Bosnia and Herzegovina  100.00    0.00
# Brazil                   66.22   33.78
# Canada                   47.98   52.02
# Colombia                100.00    0.00
# Costa Rica              100.00    0.00
# Croatia                   0.00  100.00
# Czech Republic          100.00    0.00
# Denmark                   0.00  100.00
# Finland                 100.00    0.00
# France                  100.00    0.00
# Georgia                 100.00    0.00
# Germany                  50.01   49.99
# Greece                  100.00    0.00
# India                    74.93   25.07
# Ireland                  47.52   52.48
# Israel                  100.00    0.00
# Italy                   100.00    0.00
# Mexico                  100.00    0.00
# Moldova                   0.00  100.00
# Netherlands              65.92   34.08
# New Zealand              21.45   78.55
# Nigeria                 100.00    0.00
# Philippines             100.00    0.00
# Poland                    0.00  100.00
# Portugal                100.00    0.00
# Russia                  100.00    0.00
# Singapore               100.00    0.00
# South Africa             42.56   57.44
# Sweden                   73.94   26.06
# Switzerland              50.00   50.00
# Thailand                100.00    0.00
# UK                       51.34   48.66
# USA                      47.23   52.77
#
# ================================================================================
# Variable : Occupation × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment       No     Yes   TOTAL
# Occupation
# Business     22296   21694   43990
# Corporate    28596   27026   55622
# Housewife    30600   29481   60081
# Others       24041   23387   47428
# Student      27425   26782   54207
# TOTAL       132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon Occupation ---
# Treatment      No    Yes
# Occupation
# Business    50.68  49.32
# Corporate   51.41  48.59
# Housewife   50.93  49.07
# Others      50.69  49.31
# Student     50.59  49.41
#
# ================================================================================
# Variable : SelfEmployed × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment         No     Yes   TOTAL
# SelfEmployed
# No            118819  111585  230404
# Yes            12063   14505   26568
# TOTAL         130882  126090  256972
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon SelfEmployed ---
# Treatment        No    Yes
# SelfEmployed
# No            51.57  48.43
# Yes           45.40  54.60
#
# ================================================================================
# Variable : FamilyHistory × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment          No     Yes   TOTAL
# FamilyHistory
# No             105367   56614  161981
# Yes             27591   71756   99347
# TOTAL          132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon FamilyHistory ---
# Treatment         No    Yes
# FamilyHistory
# No             65.05  34.95
# Yes            27.77  72.23
#
# ================================================================================
# Variable : DaysIndoors × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment               No     Yes   TOTAL
# DaysIndoors
# 1-14 days            29495   28103   57598
# 15-30 days           23860   23214   47074
# 31-60 days           27993   26999   54992
# Go out Every day     26605   25803   52408
# More than 2 months   25005   24251   49256
# TOTAL               132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon DaysIndoors ---
# Treatment              No    Yes
# DaysIndoors
# 1-14 days           51.21  48.79
# 15-30 days          50.69  49.31
# 31-60 days          50.90  49.10
# Go out Every day    50.77  49.23
# More than 2 months  50.77  49.23
#
# ================================================================================
# Variable : HabitsChange × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment         No     Yes   TOTAL
# HabitsChange
# Maybe          43212   41869   85081
# No             39927   38633   78560
# Yes            49819   47868   97687
# TOTAL         132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon HabitsChange ---
# Treatment        No    Yes
# HabitsChange
# Maybe         50.79  49.21
# No            50.82  49.18
# Yes           51.00  49.00
#
# ================================================================================
# Variable : MentalHealthHistory × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment                No     Yes   TOTAL
# MentalHealthHistory
# Maybe                 42971   42018   84989
# No                    48052   45975   94027
# Yes                   41935   40377   82312
# TOTAL                132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon MentalHealthHistory ---
# Treatment               No    Yes
# MentalHealthHistory
# Maybe                50.56  49.44
# No                   51.10  48.90
# Yes                  50.95  49.05
#
# ================================================================================
# Variable : IncreasingStress × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment             No     Yes   TOTAL
# IncreasingStress
# Maybe              46493   44204   90697
# No                 41945   40263   82208
# Yes                44520   43903   88423
# TOTAL             132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon IncreasingStress ---
# Treatment            No    Yes
# IncreasingStress
# Maybe             51.26  48.74
# No                51.02  48.98
# Yes               50.35  49.65
#
# ================================================================================
# Variable : MoodSwings × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment       No     Yes   TOTAL
# MoodSwings
# High         41545   40375   81920
# Low          45384   43809   89193
# Medium       46029   44186   90215
# TOTAL       132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon MoodSwings ---
# Treatment      No    Yes
# MoodSwings
# High        50.71  49.29
# Low         50.88  49.12
# Medium      51.02  48.98
#
# ================================================================================
# Variable : SocialWeakness × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment           No     Yes   TOTAL
# SocialWeakness
# Maybe            47578   45693   93271
# No               44679   43267   87946
# Yes              40701   39410   80111
# TOTAL           132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon SocialWeakness ---
# Treatment          No    Yes
# SocialWeakness
# Maybe           51.01  48.99
# No              50.80  49.20
# Yes             50.81  49.19
#
# ================================================================================
# Variable : CopingStruggles × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment            No     Yes   TOTAL
# CopingStruggles
# No                71280   67971  139251
# Yes               61678   60399  122077
# TOTAL            132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon CopingStruggles ---
# Treatment           No    Yes
# CopingStruggles
# No               51.19  48.81
# Yes              50.52  49.48
#
# ================================================================================
# Variable : WorkInterest × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment         No     Yes   TOTAL
# WorkInterest
# Maybe          45880   44151   90031
# No             48127   46333   94460
# Yes            38951   37886   76837
# TOTAL         132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon WorkInterest ---
# Treatment        No    Yes
# WorkInterest
# Maybe         50.96  49.04
# No            50.95  49.05
# Yes           50.69  49.31
#
# ================================================================================
# Variable : SocialWeakness.1 × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment             No     Yes   TOTAL
# SocialWeakness.1
# Maybe              47578   45693   93271
# No                 44679   43267   87946
# Yes                40701   39410   80111
# TOTAL             132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon SocialWeakness.1 ---
# Treatment            No    Yes
# SocialWeakness.1
# Maybe             51.01  48.99
# No                50.80  49.20
# Yes               50.81  49.19
#
# ================================================================================
# Variable : MentalHealthInterview × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment                  No     Yes   TOTAL
# MentalHealthInterview
# Maybe                   28902   18942   47844
# No                     100508  104969  205477
# Yes                      3548    4459    8007
# TOTAL                  132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon MentalHealthInterview ---
# Treatment                 No    Yes
# MentalHealthInterview
# Maybe                  60.41  39.59
# No                     48.91  51.09
# Yes                    44.31  55.69
#
# ================================================================================
# Variable : CareOptions × Treatment
# ================================================================================
#
# --- EFFECTIFS ---
# Treatment        No     Yes   TOTAL
# CareOptions
# No            65591   43381  108972
# Not sure      42394   25865   68259
# Yes           24973   59124   84097
# TOTAL        132958  128370  261328
#
# --- PROPORTIONS EN LIGNE (%) - Distribution de Treatment selon CareOptions ---
# Treatment       No    Yes
# CareOptions
# No           60.19  39.81
# Not sure     62.11  37.89
# Yes          29.70  70.30
#
# ================================================================================
# ANALYSE TERMINÉE
# ================================================================================

# %% [markdown]
# - Les femmes aurais une plus grande probabilité d'être sous traitement que les hommes
# - Avoir un antécedent familliale augmenterais les probabilités d'être sous traitements
# - Avoir une option d'assurance santé augmenterais les chances d'être sous traitements
# Faits intéressants et contre-intuitif :
#     - Allez souvent dehors ou non ne changerais rien à la probabilité d'être sous traitements
#     - Avoir des antécedants de santé mentale ne changerais pas les probabilités
#     - Les variations de l'humeur n'entrainerait pas de hausse de probabilité d'être sous traitements
#     - Les difficultés à gérer les émotions n'augmentent pas les probabilités d'être sous traitements

# %% [markdown]
# ### b. Chi^2 et p_value

# %%
def test_chi2(df, target='Treatment'):
    """Calcule Chi² et p-value pour toutes les variables vs la cible."""
    print("="*80 + f"\nTEST DU CHI² - ASSOCIATION AVEC {target}\n" + "="*80)
    
    resultats = []
    for col in df.columns:
        if col == target:
            continue
        
        # Tableau de contingence sans marges
        contingence = pd.crosstab(df[col], df[target])
        
        # Test du Chi²
        chi2, p_value, _, _ = chi2_contingency(contingence)
        chi2 = float(chi2) # type: ignore
        p_value = float(p_value) # type: ignore
        
        # Format p-value
        p_str = "< 0.001" if p_value < 0.001 else round(p_value, 4)
        
        resultats.append({
            'Variable': col,
            'Chi²': round(chi2, 2),
            'p-value': p_str
        })
    
    # Affichage sous forme de DataFrame trié par Chi²
    resultats_df = pd.DataFrame(resultats).sort_values('Chi²', ascending=False)
    print("\n" + resultats_df.to_string(index=False))
    
    print("\n" + "="*80)
    print("Interprétation : p-value < 0.05 = association statistiquement significative")
    print("="*80 + "\nANALYSE TERMINÉE\n" + "="*80)
    
    return resultats_df

# Calcul pour toutes les variables
resultats_chi2 = test_chi2(df)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'mentalhealth (Python 3.10.11)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### c. Cramér's V

# %%
def cramer_v(df, target='Treatment'):
    """Calcule Cramér's V pour mesurer la force d'association entre variables."""
    print("="*80 + f"\nCRAMÉR'S V - FORCE D'ASSOCIATION AVEC {target}\n" + "="*80)
    
    resultats = []
    for col in df.columns:
        if col == target:
            continue
        
        # Tableau de contingence
        contingence = pd.crosstab(df[col], df[target])
        
        # Chi² et dimensions
        chi2, _, _, _ = chi2_contingency(contingence)
        n = contingence.sum().sum()
        r, c = contingence.shape
        
        # Cramér's V = sqrt(Chi² / (n * (min(r,c) - 1)))
        v = np.sqrt(chi2 / (n * (min(r, c) - 1)))
        
        # Interprétation
        if v < 0.1:
            force = "Négligeable"
        elif v < 0.3:
            force = "Faible"
        elif v < 0.5:
            force = "Modéré"
        else:
            force = "Fort"
        
        resultats.append({
            'Variable': col,
            "Cramér's V": round(v, 3),
            'Force': force
        })
    
    # Affichage trié par Cramér's V
    resultats_df = pd.DataFrame(resultats).sort_values("Cramér's V", ascending=False)
    print("\n" + resultats_df.to_string(index=False))
    
    print("\n" + "="*80)
    print("Interprétation : 0-0.1 (négligeable), 0.1-0.3 (faible), 0.3-0.5 (modéré), >0.5 (fort)")
    print("="*80 + "\nANALYSE TERMINÉE\n" + "="*80)
    
    return resultats_df

# Calcul pour toutes les variables
resultats_cramer = cramer_v(df)
# Out:
# ================================================================================
# CRAMÉR'S V - FORCE D'ASSOCIATION AVEC Treatment
# ================================================================================
#
#              Variable  Cramér's V       Force
#         FamilyHistory       0.362      Modéré
#           CareOptions       0.292      Faible
#               Country       0.259      Faible
#                Gender       0.148      Faible
# MentalHealthInterview       0.092 Négligeable
#          SelfEmployed       0.038 Négligeable
#      IncreasingStress       0.008 Négligeable
#       CopingStruggles       0.007 Négligeable
#            Occupation       0.006 Négligeable
#   MentalHealthHistory       0.005 Négligeable
#           DaysIndoors       0.004 Négligeable
#          HabitsChange       0.002 Négligeable
#            MoodSwings       0.002 Négligeable
#        SocialWeakness       0.002 Négligeable
#          WorkInterest       0.002 Négligeable
#      SocialWeakness.1       0.002 Négligeable
#
# ================================================================================
# Interprétation : 0-0.1 (négligeable), 0.1-0.3 (faible), 0.3-0.5 (modéré), >0.5 (fort)
# ================================================================================
# ANALYSE TERMINÉE
# ================================================================================

# %% [markdown]
# La conclusion de l'analyse descriptive est que le dataset pourrait soit synthétique, soit être biaisé car certains résultats sont contre intuitifs. Notamment MentalHealth history. Les données sont indiquées comme étant "self-reported", les biais et la mauvaise qualité des données peuvent venir de là. L'objectif ici, avec Catboost sera de voir la différence entre Cramér's et le SHAP. Les relations non linéaires capturées pas CatBoost pourrait faire ressortir des variables prédictives.
